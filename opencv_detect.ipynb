# %% [markdown]
# <a href="https://colab.research.google.com/github/jcshim/colab/blob/master/opencv_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y libsm6 libxext6

# %%
# !pip install -q -U opencv-python
# Out:
#      |████████████████████████████████| 28.2MB 106kB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-eabdc2e8-9bdd-4a1a-b999-e917e644b5ab" name="files[]" multiple disabled />
#      <output id="result-eabdc2e8-9bdd-4a1a-b999-e917e644b5ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving jcshim.png to jcshim.png

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
img = cv2.imread('jcshim.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[115  65 154 154]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img)
